# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: #FF6347;">Self-Guided Lab: Retrieval-Augmented Generation (RAGs)</h1>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZ3FsdzRveTBrenMxM3VnbDMwaTJxN2NnZm50aGFibXk1NzNnY2Q0MCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/LR5ZBwZHv02lmpVoEU/giphy.gif" alt="NLP Gif" style="width: 300px; height: 150px; object-fit: cover; object-position: center;">
# </div>

# %% [markdown]
# <h1 style="color: #FF6347;">Data Storage & Retrieval</h1>

# %% [markdown]
# <h2 style="color: #FF8C00;">PyPDFLoader</h2>
#
# `PyPDFLoader` is a lightweight Python library designed to streamline the process of loading and parsing PDF documents for text processing tasks. It is particularly useful in Retrieval-Augmented Generation workflows where text extraction from PDFs is required.
#
# - **What Does PyPDFLoader Do?**
#   - Extracts text from PDF files, retaining formatting and layout.
#   - Simplifies the preprocessing of document-based datasets.
#   - Supports efficient and scalable loading of large PDF collections.
#
# - **Key Features:**
#   - Compatible with popular NLP libraries and frameworks.
#   - Handles multi-page PDFs and embedded images (e.g., OCR-compatible setups).
#   - Provides flexible configurations for structured text extraction.
#
# - **Use Cases:**
#   - Preparing PDF documents for retrieval-based systems in RAGs.
#   - Automating the text extraction pipeline for document analysis.
#   - Creating datasets from academic papers, technical manuals, and reports.

# %%
# %pip install langchain langchain_community pypdf
# %pip install termcolor langchain_openai langchain-huggingface sentence-transformers chromadb langchain_chroma tiktoken openai python-dotenv
# Out:
# Requirement already satisfied: langchain in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (1.3.0)
# Requirement already satisfied: langchain_community in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (0.4.1)
# Requirement already satisfied: pypdf in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (6.11.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.2.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (1.0.7)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.0.49)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.33.1)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (3.13.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.14.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.8.4)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.15.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (3.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.4.22)
# Requirement already satisfied: greenlet>=1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.5.0)
# Requirement already satisfied: anyio in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain) (1.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: termcolor in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (3.3.0)
# Requirement already satisfied: langchain_openai in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-huggingface in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (1.2.2)
# Requirement already satisfied: sentence-transformers in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (5.5.0)
# Requirement already satisfied: chromadb in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (1.5.9)
# Requirement already satisfied: langchain_chroma in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (1.1.0)
# Requirement already satisfied: tiktoken in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# Requirement already satisfied: openai in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (2.36.0)
# Requirement already satisfied: python-dotenv in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain_openai) (1.4.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-huggingface) (1.14.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (5.8.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.12.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.4.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.47.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: regex in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from tiktoken) (2026.5.9)
# Requirement already satisfied: requests in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from tiktoken) (2.33.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from openai) (0.14.0)
# Requirement already satisfied: sniffio in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: packaging>=24.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from build>=1.0.3->chromadb) (26.0)
# Requirement already satisfied: pyproject_hooks in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python311\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: certifi in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.8.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.15.0)
# Requirement already satisfied: flatbuffers in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests->tiktoken) (3.4.7)
# Requirement already satisfied: zipp>=3.20 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain_openai) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain_openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain_openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.25.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import warnings

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter, RecursiveCharacterTextSplitter

warnings.filterwarnings("ignore")

# %% [markdown]
# <h3 style="color: #FF8C00;">Loading the Documents</h3>

# %%
# File path for the document

file_path = "../ai-for-everyone.pdf"

# %% [markdown]
# <h3 style="color: #FF8C00;">Documents into pages</h3>
#
# The `PyPDFLoader` library allows efficient loading and splitting of PDF documents into smaller, manageable parts for NLP tasks.
#
# This functionality is particularly useful in workflows requiring granular text processing, such as Retrieval-Augmented Generation (RAG).

# %%
import os

for root, dirs, files in os.walk(".."):
    for file in files:
        if file.lower().endswith(".pdf"):
            print(os.path.join(root, file))
# Out:
# ..\ai-for-everyone.pdf

# %%
# Load and split the document
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()
len(pages)
# Out:
# 297

# %% [markdown]
# <h3 style="color: #FF8C00;">Pages into Chunks</h3>
#
#
# ####  RecursiveCharacterTextSplitter in LangChain
#
# The `RecursiveCharacterTextSplitter` is the **recommended splitter** in LangChain when you want to break down long documents into smaller, semantically meaningful chunks — especially useful in **RAG pipelines**, where clean context chunks lead to better LLM responses.
#
# ####  Parameters
#
# | Parameter       | Description                                                                 |
# |-----------------|-----------------------------------------------------------------------------|
# | `chunk_size`    | The **maximum number of characters** allowed in a chunk (e.g., `1000`).     |
# | `chunk_overlap` | The number of **overlapping characters** between consecutive chunks (e.g., `200`). This helps preserve context continuity. |
#
# ####  How it works
# `RecursiveCharacterTextSplitter` attempts to split the text **intelligently**, trying the following separators in order:
# 1. Paragraphs (`"\n\n"`)
# 2. Lines (`"\n"`)
# 3. Sentences or words (`" "`)
# 4. Individual characters (as a last resort)
#
# This makes it ideal for handling **natural language documents**, such as PDFs, articles, or long reports, without breaking sentences or paragraphs in awkward ways.

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
chunks = text_splitter.split_documents(pages)

len(chunks)
# Out:
# 1096

# %% [markdown]
# ####  Alternative: CharacterTextSplitter
#
# `CharacterTextSplitter` is a simpler splitter that breaks text into chunks based **purely on character count**, without trying to preserve any natural language structure.
#
# ##### Example:
# ```python
# from langchain.text_splitter import CharacterTextSplitter
#
# text_splitter = CharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
# ````
#
# This method is faster and more predictable but may split text in the middle of a sentence or paragraph, which can hurt performance in downstream tasks like retrieval or QA.
#
# ---
#
# #### Comparison Table
#
# | Feature                        | RecursiveCharacterTextSplitter | CharacterTextSplitter     |
# | ------------------------------ | ------------------------------ | ------------------------- |
# | Structure-aware splitting      |  Yes                          |  No                      |
# | Preserves sentence/paragraphs  |  Yes                          |  No                      |
# | Risk of splitting mid-sentence |  Minimal                     |  High                   |
# | Ideal for RAG/document QA      |  Highly recommended           |  Only if structured text |
# | Performance speed              |  Slightly slower             |  Faster                  |
#
# ---
#
# #### Recommendation
#
# Use `RecursiveCharacterTextSplitter` for most real-world document processing tasks, especially when building RAG pipelines or working with structured natural language content like PDFs or articles.

# %% [markdown]
# ## Best Practices for Choosing Chunk Size in RAG
#
# ### Best Practices for Chunk Size in RAG
#
# | Factor                      | Recommendation                                                                                                                                                                                          |
# | ---------------------------| ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **LLM context limit**       | Choose a chunk size that lets you retrieve multiple chunks **without exceeding the model’s token limit**. For example, GPT-4o supports 128k tokens, but with GPT-3.5 (16k) or GPT-4 (32k), keep it modest. |
# | **Chunk size (in characters)** | Typically: **500–1,000 characters** per chunk → ~75–200 tokens. This fits well for retrieval + prompt without context overflow.                                                                           |
# | **Chunk size (in tokens)**  | If using token-based splitter (e.g. `TokenTextSplitter`): aim for **100–300 tokens** per chunk.                                                                                                            |
# | **Chunk overlap**           | Use **overlap of 10–30%** (e.g., 100–300 characters or ~50 tokens) to preserve context across chunk boundaries and avoid cutting off important ideas mid-sentence.                                        |
# | **Document structure**      | Use **`RecursiveCharacterTextSplitter`** to preserve semantic boundaries (paragraphs, sentences) instead of arbitrary cuts.                                                                                |
# | **Task type**               | For **question answering**, smaller chunks (~500–800 chars) reduce noise.<br>For **summarization**, slightly larger chunks (~1000–1500) are OK.                                                          |
# | **Embedding model**         | Some models (e.g., `text-embedding-3-large`) can handle long input. But still, smaller chunks give **finer-grained retrieval**, which improves relevance.                                                  |
# | **Query type**              | If users ask **very specific questions**, small focused chunks are better. For broader queries, bigger chunks might help.                                                                                  |
#
#
# ### Rule of Thumb
#
# | Use Case                 | Chunk Size      | Overlap |
# | ------------------------| --------------- | ------- |
# | Factual Q&A              | 500–800 chars   | 100–200 |
# | Summarization            | 1000–1500 chars | 200–300 |
# | Technical documents      | 400–700 chars   | 100–200 |
# | Long reports/books       | 800–1200 chars  | 200–300 |
# | Small LLMs (≤16k tokens) | ≤800 chars      | 100–200 |
#
#
# ### Avoid
#
# - Chunks >2000 characters: risks context overflow.
# - No overlap: may lose key information between chunks.

# %% [markdown]
# <h2 style="color: #FF8C00;">Embeddings</h2>
#
# Embeddings transform text into dense vector representations, capturing semantic meaning and contextual relationships. They are essential for efficient document retrieval and similarity analysis.
#
# - **What are OpenAI Embeddings?**
#   - Pre-trained embeddings like `text-embedding-3-large` generate high-quality vector representations for text.
#   - Encapsulate semantic relationships in the text, enabling robust NLP applications.
#
# - **Key Features of `text-embedding-3-large`:**
#   - Large-scale embedding model optimized for accuracy and versatility.
#   - Handles diverse NLP tasks, including retrieval, classification, and clustering.
#   - Ideal for applications with high-performance requirements.
#
# - **Benefits:**
#   - Reduces the need for extensive custom training.
#   - Provides state-of-the-art performance in retrieval-augmented systems.
#   - Compatible with RAGs to create powerful context-aware models.

# %%
from langchain.embeddings import OpenAIEmbeddings
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from langchain.embeddings import OpenAIEmbeddings
#       2 from dotenv import load_dotenv
#
# ImportError: cannot import name 'OpenAIEmbeddings' from 'langchain.embeddings' (c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\embeddings\__init__.py)

# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings

load_dotenv()

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")

# %%
print(api_key is not None)
# Out:
# True

# %% [markdown]
# <h2 style="color: #FF8C00;">ChromaDB</h2>
#
# ChromaDB is a versatile vector database designed for efficiently storing and retrieving embeddings. It integrates seamlessly with embedding models to enable high-performance similarity search and context-based retrieval.
#
# ### Workflow Overview:
# - **Step 1:** Generate embeddings using a pre-trained model (e.g., OpenAI's `text-embedding-3-large`).
# - **Step 2:** Store the embeddings in ChromaDB for efficient retrieval and similarity calculations.
# - **Step 3:** Use the stored embeddings to perform searches, matching, or context-based retrieval.
#
# ### Key Features of ChromaDB:
# - **Scalability:** Handles large-scale datasets with optimized indexing and search capabilities.
# - **Speed:** Provides fast and accurate retrieval of embeddings for real-time applications.
# - **Integration:** Supports integration with popular frameworks and libraries for embedding generation.

# %%
from langchain.vectorstores import Chroma
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from langchain.vectorstores import Chroma
#
# ModuleNotFoundError: No module named 'langchain.vectorstores'

# %%
from langchain_chroma import Chroma

# %%
db = Chroma.from_documents(chunks, embeddings, persist_directory="./chroma_db_LAB")
print("ChromaDB created with document embeddings.")
# Out:
# ChromaDB created with document embeddings.

# %% [markdown]
# <h1 style="color: #FF6347;">Retrieving Documents</h1>

# %% [markdown]
# ### Exercice1: Write a user question that someone might ask about your book’s topic or content.

# %%
user_question = "How does the book explain what AI is and why it matters for people without a technical background?" # User question
retrieved_docs = db.similarity_search(user_question, k=10) # k is the number of documents to retrieve

# %%
len(retrieved_docs)
# Out:
# 10

# %%
# Display top results
for i, doc in enumerate(retrieved_docs[:3]): # Display top 3 results
    print(f"Document {i+1}:\n{doc.page_content[36:1000]}") # Display content
# Out:
# Document 1:
# rs. The discussion about how to define
# AI cannot be settled in one definition, let alone one book. It is an important
# starting point, however, and Part 1 and Part 2 of this book will unpack several
# approaches to defining AI.
# The Realities of AI for Some vs. the Ideals of AI for Everyone
# Visions of AI in Policies and Ethics
# Examining AI policies and ethics helps us to explore questions of what type of
# AI we want/need, how its development should look like and how we deal with
# its impact. Policy development happens at several levels and includes a number
# of stakeholders: national governments, intergovernmental organisations, cor -
# porations, professional associations and academics.
# Document 2:
# , are financially strong enough to hire the
# brightest AI talent and have access to the gigantic datasets that are needed to
# train machine learning and deep learning (AI) models. This context makes it
# very clear why we need to ask critical questions about AI and power.
# Conceptualising AI – What AI Are We Talking About?
# Before understanding what type of AI we want, we need to understand what AI
# we have. This is an area of significant debate, and the book opens by exploring
# the varying approaches to how we define AI.
# The Origins of AI
# It is easy to forget that AI has been with us for more than 60 years. Despite
# the flash of excitement and anxiety that feels so recent, AI itself is not a new
# phenomenon. The name Artificial Intelligence (AI) was coined in the mid-
# 1950s at a series of academic workshops organised at Dartmouth College, New
# Hampshire (USA). A group of scientists, led by mathematics professor John
# Document 3:
#  accessible for everyone. Further in this intro-
# duction, I elaborate on this and I make the case for a radical democratisation of
# AI, and why we need to put power at the centre for achieving this.
# The contributions in this book braid discussion of power and critique with
# three strands: AI – Humans vs. Machines, Discourses and Myths About AI and
# AI Power and Inequalities.
# Part 1: AI – Humans vs. Machines – deals with the history and conceptualisa-
# tion of AI and what is at stake in its development. This section looks at different
# perspectives about what characterises machine intelligence and how it might
# be important to further radical humanism in the era of automation and AI.
# Part 2: Discourses and Myths About AI – analyses how AI is framed in popu-
# lar and scholarly discussions and investigates the normative projections of what
# AI should be and what it should do. This section poses critical questions about

# %% [markdown]
# <h2 style="color: #FF8C00;">Preparing Content for GenAI</h2>

# %%
def _get_document_prompt(docs):
    prompt = "\n"
    for doc in docs:
        prompt += "\nContent:\n"
        prompt += doc.page_content + "\n\n"
    return prompt

# %%
# Generate a formatted context from the retrieved documents
formatted_context = _get_document_prompt(retrieved_docs)
print("Context formatted for GPT model.")
# Out:
# Context formatted for GPT model.

# %% [markdown]
# <h2 style="color: #FF8C00;">ChatBot Architecture</h2>

# %% [markdown]
# ### Exercice2: Write a prompt that is relevant and tailored to the content and style of your book.

# %%
prompt = f"""
You are a helpful AI learning assistant answering questions about the book "AI for Everyone".

Your task is to answer the user's question using only the retrieved context provided below.

Rules:
- Use only the information in the context.
- Do not invent facts or add outside knowledge.
- If the context does not contain enough information, say: "The provided context does not contain enough information to answer this question."
- Explain the answer clearly for a non-technical audience.
- Keep the answer concise and structured.

Context:
{formatted_context}

User question:
{user_question}

Answer:
"""

# %%
import openai

# %% [markdown]
# ### Exercice3: Tune parameters like temperature, and penalties to control how creative, focused, or varied the model's responses are.

# %%
client = openai.OpenAI()

# %%
model_params = {
    "model": "gpt-4o-mini",
    "temperature": 0.3,          # focused, less creative
    "max_tokens": 500,           # clear but not too long
    "top_p": 1.0,                # standard setting
    "frequency_penalty": 0.2,    # slightly reduce repetition
    "presence_penalty": 0.0      # stay close to the retrieved context
}

# %%
# Set up GPT client and parameters
model_params_creative = {
    'model': 'gpt-4o-mini',
    'temperature': 0.7,  # Increase creativity
    'max_tokens': 700,  # Allow for longer responses
    'top_p': 0.9,        # Use nucleus sampling
    'frequency_penalty': 0.4,  # Reduce repetition
    'presence_penalty': 0.3   # Encourage new topics
}

# %% [markdown]
# <h1 style="color: #FF6347;">Response</h1>

# %%
messages = [{'role': 'user', 'content': prompt}]
completion = client.chat.completions.create(messages=messages, **model_params, timeout=120)

# %%
answer_focused = completion.choices[0].message.content
print(answer_focused)
# Out:
# The book explains that AI, or Artificial Intelligence, is a concept that has been around for over 60 years and refers to systems that mimic intelligent human behaviors. It emphasizes that defining AI is complex, with various approaches to understanding what it is.
#
# For people without a technical background, the book highlights the importance of discussing AI's impact on society, particularly regarding power dynamics and inequalities. It argues that as AI becomes more integrated into our lives, it's crucial to ask fundamental questions about who benefits from AI and how its development should be guided to ensure accessibility for everyone.
#
# The book is structured in three parts:
#
# 1. **AI – Humans vs. Machines**: This section explores the history and different perspectives on AI.
# 2. **Discourses and Myths About AI**: This part examines how AI is framed in discussions and challenges common misconceptions.
# 3. **AI Power and Inequalities**: This section critically looks at who has the power in the AI landscape and the potential inequalities that may arise.
#
# Overall, the book aims to make the discussion about AI relevant to everyone, encouraging a broader understanding of its implications beyond technical details.

# %%
completion_creative = client.chat.completions.create(
    messages=messages,
    **model_params_creative,
    timeout=120
)

answer_creative = completion_creative.choices[0].message.content
print("CREATIVE ANSWER:\n")
print(answer_creative)
# Out:
# CREATIVE ANSWER:
#
# The book explains that AI (Artificial Intelligence) is a concept that involves mimicking intelligent human behaviors and has been around for over 60 years. It emphasizes that there isn't a single definition of AI, as it encompasses various approaches and understandings.
#
# For people without a technical background, the book highlights the importance of discussing AI because it affects everyone in society. It addresses critical questions about how AI can benefit all individuals, who holds the power to make decisions about its development, and what inequalities may arise from it. The book aims to democratize access to AI benefits and encourages readers to think critically about its implications, making it relevant for all, regardless of their technical expertise.
#
# Overall, the book seeks to foster a deeper understanding of AI's impact on society by examining its definitions, history, and potential inequalities, ensuring that these discussions are accessible to everyone.

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:824/1*GK56xmDIWtNQAD_jnBIt2g.png" alt="NLP Gif" style="width: 500px">

# %% [markdown]
# <h2 style="color: #FF6347;">Cosine Similarity</h2>
#
# **Cosine similarity** is a metric used to measure the alignment or similarity between two vectors, calculated as the cosine of the angle between them. It is the **most common metric used in RAG pipelines** for vector retrieval.. It provides a scale from -1 to 1:
#
# - **-1**: Vectors are completely opposite.
# - **0**: Vectors are orthogonal (uncorrelated or unrelated).
# - **1**: Vectors are identical.

# %% [markdown]
# <img src="https://storage.googleapis.com/lds-media/images/cosine-similarity-vectors.original.jpg" alt="NLP Gif" style="width: 700px">

# %% [markdown]
# <h2 style="color: #FF6347;">Keyword Highlighting</h2>
#
# Highlighting important keywords helps users quickly understand the relevance of the retrieved text to their query.

# %%
from termcolor import colored

# %% [markdown]
# The `highlight_keywords` function is designed to highlight specific keywords within a given text. It replaces each keyword in the text with a highlighted version using the `colored` function from the `termcolor` library.

# %%
def highlight_keywords(text, keywords):
    for keyword in keywords:
        text = text.replace(keyword, colored(keyword, 'green', attrs=['bold']))
    return text

# %% [markdown]
# ### Exercice4: add your keywords

# %%
query_keywords = [] # add your keywords
for i, doc in enumerate(retrieved_docs[:1]):
    snippet = doc.page_content[:200]
    highlighted = highlight_keywords(snippet, query_keywords)
    print(f"Snippet {i+1}:\n{highlighted}\n{'-'*80}")

# %% [markdown]
# 1. `query_keywords` is a list of keywords to be highlighted.
# 2. The loop iterates over the first document in retrieved_docs.
# 3. For each document, a snippet of the first 200 characters is extracted.
# 4. The highlight_keywords function is called to highlight the keywords in the snippet.
# 5. The highlighted snippet is printed along with a separator line.

# %% [markdown]
# <h1 style="color: #FF6347;">Bonus</h1>

# %% [markdown]
# **Try loading one of your own PDF books and go through the steps again to explore how the pipeline works with your content**:
